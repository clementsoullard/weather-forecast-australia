# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
def plot_feature_importances(clf):
    n_features = X.shape[1]
    plt.figure(figsize = (10, 30))
    plt.barh(range(n_features), clf.feature_importances_, align ='center')
    plt.yticks(np.arange(n_features),X.columns)
    plt.xlabel('Importance des features')
    plt.ylabel('Feature')
    plt.ylim(-1, n_features)

# %%
data=pd.read_csv('C:/Users/theop\Documents/000AAA DATASCIENTIST/000 PROJET AUS\meteo_knn_imputer.csv')
data.head(3)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90122 entries, 0 to 90121
# Data columns (total 96 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   MinTemp                    90122 non-null  float64
#  1   MaxTemp                    90122 non-null  float64
#  2   Rainfall                   90122 non-null  float64
#  3   Evaporation                90122 non-null  float64
#  4   Sunshine                   90122 non-null  float64
#  5   WindGustSpeed              90122 non-null  float64
#  6   WindSpeed9am               90122 non-null  float64
#  7   WindSpeed3pm               90122 non-null  float64
#  8   Humidity9am                90122 non-null  float64
#  9   Humidity3pm                90122 non-null  float64
#  10  Pressure9am                90122 non-null  float64
#  11  Pressure3pm                90122 non-null  float64
#  12  Cloud9am                   90122 non-null  float64
#  13  Cloud3pm                   90122 non-null  float64
#  14  Temp9am                    90122 non-null  float64
#  15  Temp3pm                    90122 non-null  float64
#  16  RainToday                  90122 non-null  float64
#  17  RainTomorrow               90122 non-null  float64
#  18  Location_Adelaide          90122 non-null  float64
#  19  Location_Albany            90122 non-null  float64
#  20  Location_AliceSprings      90122 non-null  float64
#  21  Location_Brisbane          90122 non-null  float64
#  22  Location_Cairns            90122 non-null  float64
#  23  Location_Canberra          90122 non-null  float64
#  24  Location_Cobar             90122 non-null  float64
#  25  Location_CoffsHarbour      90122 non-null  float64
#  26  Location_Dartmoor          90122 non-null  float64
#  27  Location_Darwin            90122 non-null  float64
#  28  Location_Hobart            90122 non-null  float64
#  29  Location_Melbourne         90122 non-null  float64
#  30  Location_MelbourneAirport  90122 non-null  float64
#  31  Location_Mildura           90122 non-null  float64
#  32  Location_Moree             90122 non-null  float64
#  33  Location_MountGambier      90122 non-null  float64
#  34  Location_NorfolkIsland     90122 non-null  float64
#  35  Location_Nuriootpa         90122 non-null  float64
#  36  Location_PearceRAAF        90122 non-null  float64
#  37  Location_Perth             90122 non-null  float64
#  38  Location_PerthAirport      90122 non-null  float64
#  39  Location_Portland          90122 non-null  float64
#  40  Location_Sale              90122 non-null  float64
#  41  Location_Sydney            90122 non-null  float64
#  42  Location_SydneyAirport     90122 non-null  float64
#  43  Location_Townsville        90122 non-null  float64
#  44  Location_WaggaWagga        90122 non-null  float64
#  45  Location_Watsonia          90122 non-null  float64
#  46  Location_Williamtown       90122 non-null  float64
#  47  Location_Woomera           90122 non-null  float64
#  48  WindGustDir_E              90122 non-null  float64
#  49  WindGustDir_ENE            90122 non-null  float64
#  50  WindGustDir_ESE            90122 non-null  float64
#  51  WindGustDir_N              90122 non-null  float64
#  52  WindGustDir_NE             90122 non-null  float64
#  53  WindGustDir_NNE            90122 non-null  float64
#  54  WindGustDir_NNW            90122 non-null  float64
#  55  WindGustDir_NW             90122 non-null  float64
#  56  WindGustDir_S              90122 non-null  float64
#  57  WindGustDir_SE             90122 non-null  float64
#  58  WindGustDir_SSE            90122 non-null  float64
#  59  WindGustDir_SSW            90122 non-null  float64
#  60  WindGustDir_SW             90122 non-null  float64
#  61  WindGustDir_W              90122 non-null  float64
#  62  WindGustDir_WNW            90122 non-null  float64
#  63  WindGustDir_WSW            90122 non-null  float64
#  64  WindDir9am_E               90122 non-null  float64
#  65  WindDir9am_ENE             90122 non-null  float64
#  66  WindDir9am_ESE             90122 non-null  float64
#  67  WindDir9am_N               90122 non-null  float64
#  68  WindDir9am_NE              90122 non-null  float64
#  69  WindDir9am_NNE             90122 non-null  float64
#  70  WindDir9am_NNW             90122 non-null  float64
#  71  WindDir9am_NW              90122 non-null  float64
#  72  WindDir9am_S               90122 non-null  float64
#  73  WindDir9am_SE              90122 non-null  float64
#  74  WindDir9am_SSE             90122 non-null  float64
#  75  WindDir9am_SSW             90122 non-null  float64
#  76  WindDir9am_SW              90122 non-null  float64
#  77  WindDir9am_W               90122 non-null  float64
#  78  WindDir9am_WNW             90122 non-null  float64
#  79  WindDir9am_WSW             90122 non-null  float64
#  80  WindDir3pm_E               90122 non-null  float64
#  81  WindDir3pm_ENE             90122 non-null  float64
#  82  WindDir3pm_ESE             90122 non-null  float64
#  83  WindDir3pm_N               90122 non-null  float64
#  84  WindDir3pm_NE              90122 non-null  float64
#  85  WindDir3pm_NNE             90122 non-null  float64
#  86  WindDir3pm_NNW             90122 non-null  float64
#  87  WindDir3pm_NW              90122 non-null  float64
#  88  WindDir3pm_S               90122 non-null  float64
#  89  WindDir3pm_SE              90122 non-null  float64
#  90  WindDir3pm_SSE             90122 non-null  float64
#  91  WindDir3pm_SSW             90122 non-null  float64
#  92  WindDir3pm_SW              90122 non-null  float64
#  93  WindDir3pm_W               90122 non-null  float64
#  94  WindDir3pm_WNW             90122 non-null  float64
#  95  WindDir3pm_WSW             90122 non-null  float64
# dtypes: float64(96)
# memory usage: 66.0 MB

# %%
X = data.drop('RainTomorrow', axis = 1)
y = data['RainTomorrow']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state = 16)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 200)

# %%
rf.fit(X_train,y_train)
display(rf.score(X_train,y_train))
display(rf.score(X_test,y_test))
y_pred = rf.predict(X_test)
# Out:
# 1.0
# 0.860748959778086

# %% [markdown]
# Importance des features selon la fonction plot_features_importances

# %%
plot_feature_importances(rf)

# %% [markdown]
# ACP

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import seaborn as sns

### BROUILLON

n = X_train.shape[1]

pca = PCA(n_components=2)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

X_new = pca.fit_transform(X_train_scaled)

coeff = pca.components_.transpose()

xs = X_new[:, 0]
ys = X_new[:, 1]
scalex = 1.0/(xs.max() - xs.min())
scaley = 1.0/(ys.max() - ys.min())


principalDf = pd.DataFrame({'PC1': xs*scalex, 'PC2': ys * scaley})

y_train_pred = rf.predict(X_train_scaled)
finalDF = pd.concat([principalDf, pd.Series(
    y_train_pred, name='RainTomorrow')], axis=1)


plt.figure(figsize=(13, 10))

sns.scatterplot(x='PC1', y='PC2', hue='RainTomorrow', data=finalDF, alpha=0.5)

for i in range(n):
    plt.arrow(0, 0, coeff[i, 0]*1.5, coeff[i, 1]*1.5,
              color='k', alpha=0.5, head_width=0.01, )
    plt.text(coeff[i, 0]*1.5, coeff[i, 1] * 1.5, X_train.columns[i], color='k')

plt.xlim(-0.6, 0.8)
plt.ylim(-0.8, 0.8)
# Out:
# c:\Users\theop\Documents\Python\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# (-0.8, 0.8)
